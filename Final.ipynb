# %% [markdown]
# # Examen final
# #### Matías Nahuel López - Legajo: 153.327-7

# %% [markdown]
# ## Examen final - 26/07/2023

# %% [markdown]
# ### Examen completo

# %% [markdown]
# ![Examen Final - 26/07/2023.png](attachment:20230726-1.png)

# %% [markdown]
# ### Resolución

# %% [markdown]
# #### Ejercicio 1

# %% [markdown]
# ##### Enunciado

# %% [markdown]
# ![20230726-ejercicio1.png](attachment:20230726-ejercicio1.png)

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# ##### Enunciado

# %% [markdown]
# ![20230726-ejercicio2.png](attachment:20230726-ejercicio2.png)

# %% [markdown]
# ##### Resolución

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# ##### Enunciado

# %% [markdown]
# ![20230726-ejercicio3.png](attachment:20230726-ejercicio3.png)

# %% [markdown]
# ##### Resolución

# %% [markdown]
# ## Examen final - 27/09/2023

# %% [markdown]
# ### Examen completo

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# ##### Enunciado

# %% [markdown]
# ![ejercicio2.png](attachment:ejercicio2.png)

# %% [markdown]
# ##### Resolución

# %% [markdown]
# # fin

# %% [markdown]
# # ChatGPT
# ## Final 23/06/2023
# ### Ejercicio 2
#
# #### Filtro no disipativo que se conecta a generador con:
# $R_{g} = 1Ω$
#
# $V_{0}=0V$.
#
# $ Y(s) = \frac{1}{s^2 + 2s + 1} $
#
#
# **Admitancia de Transferencia Normalizada**
#
# #### a) Síntesis gráfica del filtro normalizado para ver topología
#
# $ Y = \frac{1}{s^2 + 2s + 1} = \frac{1}{(s + 1)^2} $
#
# **Admitancia de Transferencia Directa con la Salida en Corto**
#
# #### b) Calcular el valor de las componentes de la red
#
# #### c) Verificar por AMAI e interconexión de cuadripolos para hallar el valor de k
#
# $ Y = \frac{K}{s^2 + 2s + 1} \rightarrow \frac{1}{s^2 + 2s + 1} $
#
# $ Y = \frac{V_1}{V_g} = \frac{V_2}{V_g} $
#
# $ Y_{g1} = \frac{V_1}{V_g} = 1 $
#
# $ \frac{1}{s + 1} $
#
# $ Y_{g2} = \frac{V_2}{V_g} = \frac{1}{s + 1} $
#
# $ Y = \frac{1}{(s + 1)^2} $
#
# **Admitancia de Transferencia Directa con la Salida en Corto**
#
# #### Entonces definimos:
#
# $ Y_{g1} = 1 $
#
# $ Y_{g2} = \frac{1}{s + 1} $
#
# $ \frac{1}{s + 1} $
#
# $ Y_{21} = \frac{1}{2s + 1} $
#
# $ Y_{g2} = \frac{1}{s + 1} $
#
# **Diagramas y componentes:**
#
# - **Primera etapa:**
#
# $ Y_1 = \frac{1}{s + 1} $
#
# $ Y_{12} = \frac{1}{2s + 1} $
#
# - **Segunda etapa:**
#
# $ Y_{21} = \frac{1}{2s + 1} $
#
# - **Componentes de la red:**
#
# \[ C_1 \]
# \[ L_2 \]
# \[ C_3 \]
#
# **Componentes de interconexión:**
#
# \[ L_1 \]
# \[ L_2 \]
#
# **Red final:**
#
# - C_1
# - L_2
# - C_3
